# %% [markdown]
# <a href="https://colab.research.google.com/github/AdhikKadam/Adhik_Kadam_PromptEngineering/blob/main/BITSoM_question_bank_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Consolidated Practice Question Bank
#
#
# ## Table of Contents
# - [Statistics: A/B Testing & Experiments](#statistics-ab-testing-and-experiments)
# - [Statistics: Calculation Practice](#statistics-calculation-practice)
# - [Statistics: Distributions & Descriptive Stats](#statistics-distributions-and-descriptive-stats)
# - [Statistics: Hypothesis Testing](#statistics-hypothesis-testing)
# - [Statistics: Practice Calculations](#statistics-practice-calculations)
# - [Statistics: Probability & Sampling](#statistics-probability-and-sampling)
# - [Statistics: Regression & Inference](#statistics-regression-and-inference)
# - [Statistics: Time Series (Practice)](#statistics-time-series-practice)
# - [AI-Assisted Data Analytics and Insights](#ai-assisted-data-analytics-and-insights)
# - [Applications of Neural Networks: Computer Vision](#applications-of-neural-networks-computer-vision)
# - [Applications of Neural Networks: Natural Language Processing](#applications-of-neural-networks-natural-language-processing)
# - [Building Blocks of Neural Networks](#building-blocks-of-neural-networks)
# - [Building Your First ML Model](#building-your-first-ml-model)
# - [Clustering & Time Series Forecasting](#clustering-and-time-series-forecasting)
# - [Creating dashboards for real-time business monitoring with Tableau](#creating-dashboards-for-real-time-business-monitoring-with-tableau)
# - [Data Architecture: Foundations](#data-architecture-foundations)
# - [Data Lakes](#data-lakes)
# - [Data Preprocessing & Feature Engineering](#data-preprocessing-and-feature-engineering)
# - [Data Visualization & Storytelling](#data-visualization-and-storytelling)
# - [Data Warehouses](#data-warehouses)
# - [Designing A/B Tests and Experiments](#designing-ab-tests-and-experiments)
# - [Foundation of AI Data Architecture](#foundation-of-ai-data-architecture)
# - [Hypothesis Testing Fundamentals](#hypothesis-testing-fundamentals)
# - [Introduction Time Series](#introduction-time-series)
# - [Introduction to LLM & Prompt Engineering - I](#introduction-to-llm-and-prompt-engineering---i)
# - [Introduction to Supervised learning](#introduction-to-supervised-learning)
# - [Introduction to Unsupervised learning](#introduction-to-unsupervised-learning)
# - [Introduction to machine learning](#introduction-to-machine-learning)
# - [Introduction to tool: Tableau](#introduction-to-tool-tableau)
# - [LLM & Prompt Engineering](#llm-and-prompt-engineering)
# - [Machine Learning: Fundamentals](#machine-learning-fundamentals)
# - [Multivariable Regressions](#multivariable-regressions)
# - [Neural Networks](#neural-networks)
# - [Neural Networks in Action](#neural-networks-in-action)
# - [NoSQL](#nosql)
# - [NoSQL Databases](#nosql-databases)
# - [Practical Classification Project](#practical-classification-project)
# - [Principles of effective data visualization](#principles-of-effective-data-visualization)
# - [Python Data Structures and Manipulation](#python-data-structures-and-manipulation)
# - [Python Environment, Syntax, and Control Flow](#python-environment-syntax-and-control-flow)
# - [Python: Core](#python-core)
# - [Python: Data & File I/O](#python-data-and-file-io)
# - [RDBMS & SQL](#rdbms-and-sql)
# - [Realtime Data Streams](#realtime-data-streams)
# - [Relational Database Management Systems](#relational-database-management-systems)
# - [Scripting, File I/O, and API Integration](#scripting-file-io-and-api-integration)
# - [Single Variable Regressions](#single-variable-regressions)
# - [Storytelling with data](#storytelling-with-data)
# - [Streaming & Real-time](#streaming-and-real-time)
# - [Tableau (Concepts & Best Practices)](#tableau-concepts-and-best-practices)
# - [Understanding Data Distributions](#understanding-data-distributions)
# - [Vector Databases & RAG](#vector-databases-and-rag)
# - [Vector Databases and Embedding Storage](#vector-databases-and-embedding-storage)
# - [Warehouses, Lakes, Lakehouse](#warehouses-lakes-lakehouse)
# - [Working with Libraries and Functions](#working-with-libraries-and-functions)
#
# ---

# %% [markdown]
# ## Statistics: A/B Testing & Experiments

# %% [markdown]
# ### Q1
# **If treatment assignment is randomized but you have non-compliance, an appropriate estimand to recover causal effect is often:**
#
# - **A**. ITT (intention-to-treat)
# - **B**. R²
# - **C**. MAPE
# - **D**. Bagging
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** ITT preserves randomization and estimates effect of assignment, robust to non-compliance.
#
# </details>

# %% [markdown]
# ### Q2
# **If you reduce α from 0.05 to 0.01 with fixed n and effect size, power will generally:**
#
# - **A**. Increase
# - **B**. Decrease
# - **C**. Stay same
# - **D**. Become 1
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Lower α makes rejection harder, typically reducing power unless n increases.
#
# </details>

# %% [markdown]
# ### Q3
# **If you want to reduce variance in an A/B test metric, a common method is:**
#
# - **A**. CUPED / covariate adjustment
# - **B**. Remove randomization
# - **C**. Increase noise
# - **D**. Use only smaller samples
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** CUPED uses pre-period covariates to reduce variance and boost power.
#
# </details>

# %% [markdown]
# ### Q4
# **In sequential testing, repeatedly peeking at results without correction typically:**
#
# - **A**. Reduces Type I error
# - **B**. Inflates Type I error
# - **C**. Guarantees unbiasedness
# - **D**. Removes the need for sample size planning
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Unadjusted peeking increases false positive probability.
#
# </details>

# %% [markdown]
# ### Q5
# **Random assignment in A/B tests mainly reduces:**
#
# - **A**. Measurement bias
# - **B**. Confounding/selection bias
# - **C**. Data leakage
# - **D**. Simpson’s paradox
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Randomization balances confounders in expectation.
#
# </details>

# %% [markdown]
# ### Q6
# **Running A this week and B next week is risky primarily because of:**
#
# - **A**. Overfitting
# - **B**. Time confounding/seasonality
# - **C**. Too many features
# - **D**. Perfect independence
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Time effects can be mistaken for treatment effects.
#
# </details>

# %% [markdown]
# ## Statistics: Calculation Practice

# %% [markdown]
# ### Q7
# **A 99% two-sided z critical value is approximately 2.58. What tail area is in each tail?**
#
# - **A**. 0.10
# - **B**. 0.05
# - **C**. 0.01
# - **D**. 0.005
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** D
#
# **Explanation:** 99% CI leaves 1% total in tails ⇒ 0.5% each tail = 0.005.
#
# </details>

# %% [markdown]
# ### Q8
# **A classifier confusion matrix has TP=30, FP=10, FN=20. What is precision?**
#
# - **A**. 0.50
# - **B**. 0.60
# - **C**. 0.75
# - **D**. 0.80
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** Precision = TP/(TP+FP) = 30/40 = 0.75.
#
# </details>

# %% [markdown]
# ### Q9
# **A dataset has values 3, 7, 7, 19. What is the sample variance (use denominator n−1)?**
#
# - **A**. 36
# - **B**. 48
# - **C**. 56
# - **D**. 64
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Mean=9; squared deviations: (−6)^2=36,(−2)^2=4,(−2)^2=4,(10)^2=100 sum=144; variance=144/3=48.
#
# </details>

# %% [markdown]
# ### Q10
# **A fair coin is tossed 8 times. What is the probability of exactly 5 heads? (Use C(8,5)=56)**
#
# - **A**. 56/256
# - **B**. 5/8
# - **C**. 1/2
# - **D**. 8/56
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** P = C(8,5)(1/2)^8 = 56/256.
#
# </details>

# %% [markdown]
# ### Q11
# **A population has σ=20. What sample size n is needed so that SE of mean is 2?**
#
# - **A**. 10
# - **B**. 50
# - **C**. 100
# - **D**. 400
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** SE=σ/√n=2 ⇒ √n=10 ⇒ n=100.
#
# </details>

# %% [markdown]
# ### Q12
# **A sample has n=36, sample standard deviation s=12. What is the standard error of the sample mean?**
#
# - **A**. 12
# - **B**. 6
# - **C**. 2
# - **D**. 0.33
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** SE = s/√n = 12/6 = 2.
#
# </details>

# %% [markdown]
# ### Q13
# **A test has α=0.05. If you perform 40 independent tests with all nulls true, what is the expected number of false positives?**
#
# - **A**. 0.5
# - **B**. 1
# - **C**. 2
# - **D**. 5
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** Expected false positives = mα = 40×0.05 = 2.
#
# </details>

# %% [markdown]
# ### Q14
# **A time series model has MAE=8 and RMSE=10. Which statement is most consistent?**
#
# - **A**. Errors are all identical magnitude
# - **B**. There are some larger errors (outliers) increasing RMSE
# - **C**. Model is perfect
# - **D**. RMSE must be ≤ MAE
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** RMSE penalizes large errors more, so RMSE>MAE suggests some large errors.
#
# </details>

# %% [markdown]
# ### Q15
# **If a 95% z critical value is 1.96, what is the margin of error for σ=10 and n=100?**
#
# - **A**. 0.98
# - **B**. 1.96
# - **C**. 2.50
# - **D**. 19.6
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** MOE = 1.96×(10/√100)=1.96×1=1.96.
#
# </details>

# %% [markdown]
# ### Q16
# **If P(A)=0.6, P(B)=0.5, and A and B are independent, what is P(A∩B)?**
#
# - **A**. 0.11
# - **B**. 0.30
# - **C**. 0.55
# - **D**. 1.10
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Independence: P(A∩B)=0.6×0.5=0.30.
#
# </details>

# %% [markdown]
# ### Q17
# **If the covariance between X and Y is 12 and Var(X)=16, what is the slope in the simple regression of Y on X?**
#
# - **A**. 0.5
# - **B**. 0.75
# - **C**. 1.0
# - **D**. 1.5
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** β1 = Cov(X,Y)/Var(X) = 12/16 = 0.75.
#
# </details>

# %% [markdown]
# ### Q18
# **If X~N(0,1), what is P(|X| ≤ 1.96) approximately?**
#
# - **A**. 0.50
# - **B**. 0.68
# - **C**. 0.95
# - **D**. 0.99
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** ±1.96 captures about 95% of standard normal mass.
#
# </details>

# %% [markdown]
# ### Q19
# **If you standardize a variable with mean 50 and SD 5, what is the standardized value of x=60?**
#
# - **A**. 1
# - **B**. 2
# - **C**. 10
# - **D**. -2
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** z=(60−50)/5=2.
#
# </details>

# %% [markdown]
# ### Q20
# **In a normal distribution with mean 100 and standard deviation 15, what is the z-score of x=130?**
#
# - **A**. 1
# - **B**. 2
# - **C**. 3
# - **D**. -2
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** z = (130−100)/15 = 30/15 = 2.
#
# </details>

# %% [markdown]
# ### Q21
# **In linear regression, SSE=200 and SST=500. What is R²?**
#
# - **A**. 0.2
# - **B**. 0.4
# - **C**. 0.6
# - **D**. 0.8
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** R²=1−SSE/SST = 1−200/500 = 0.6.
#
# </details>

# %% [markdown]
# ### Q22
# **Two variables have Corr(X,Y)=−0.4, σx=5, σy=10. What is Cov(X,Y)?**
#
# - **A**. −20
# - **B**. −2
# - **C**. 20
# - **D**. −50
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** Cov = r σx σy = −0.4×5×10 = −20.
#
# </details>

# %% [markdown]
# ### Q23
# **Using TP=30, FP=10, FN=20, what is F1 score?**
#
# - **A**. 0.50
# - **B**. 0.67
# - **C**. 0.71
# - **D**. 0.75
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Precision=0.75, Recall=0.60 ⇒ F1 = 2*(0.75*0.60)/(0.75+0.60)=0.6667 ≈ 0.67.
#
# </details>

# %% [markdown]
# ### Q24
# **Using TP=30, FP=10, FN=20, what is recall?**
#
# - **A**. 0.50
# - **B**. 0.60
# - **C**. 0.75
# - **D**. 0.80
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Recall = TP/(TP+FN) = 30/50 = 0.60.
#
# </details>

# %% [markdown]
# ### Q25
# **You compute a t-statistic = 2.5 with df=24. At α=0.05 two-sided, which decision is most likely? (Critical ≈ 2.064)**
#
# - **A**. Reject H0
# - **B**. Fail to reject H0
# - **C**. Cannot decide
# - **D**. Need α=0.10
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** |t|=2.5 > 2.064 ⇒ reject H0.
#
# </details>

# %% [markdown]
# ## Statistics: Distributions & Descriptive Stats

# %% [markdown]
# ### Q26
# **A Q–Q plot shows points bending away from the straight line at both tails. This suggests:**
#
# - **A**. Perfect normality
# - **B**. Heavy tails vs normal
# - **C**. No variance
# - **D**. Uniform distribution
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Tail deviations indicate heavier (or lighter) tails compared to the reference distribution.
#
# </details>

# %% [markdown]
# ### Q27
# **For a dataset, skewness ≈ 0 and kurtosis is very high. The best interpretation is:**
#
# - **A**. Symmetric but heavy-tailed
# - **B**. Right-skewed and light-tailed
# - **C**. Symmetric and uniform
# - **D**. Skewed with no outliers
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** Skewness near 0 implies symmetry; high kurtosis suggests heavy tails/outliers.
#
# </details>

# %% [markdown]
# ### Q28
# **For a right-skewed distribution, which is typically true?**
#
# - **A**. Mean < Median
# - **B**. Mean > Median
# - **C**. Mean = Median
# - **D**. Variance = 0
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Right skew pulls the mean to the right, making it larger than the median.
#
# </details>

# %% [markdown]
# ### Q29
# **Which measure is most sensitive to extreme outliers?**
#
# - **A**. Median
# - **B**. Mode
# - **C**. Mean
# - **D**. Interquartile Range (IQR)
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** Mean uses all values and is pulled by extreme observations.
#
# </details>

# %% [markdown]
# ### Q30
# **Which plot best reveals skewness and modality for a single variable?**
#
# - **A**. Histogram
# - **B**. Pie chart
# - **C**. Scatter plot
# - **D**. Radar chart
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** A histogram shows the shape, skewness, and modes.
#
# </details>

# %% [markdown]
# ### Q31
# **Which statistic is robust to outliers?**
#
# - **A**. Mean
# - **B**. Standard deviation
# - **C**. Median
# - **D**. Variance
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** Median is a robust measure of central tendency.
#
# </details>

# %% [markdown]
# ### Q32
# **You have two datasets with the same mean but different variance. Which statement is correct?**
#
# - **A**. They must have the same median
# - **B**. They must have the same distribution
# - **C**. They can look very different
# - **D**. They must have the same skewness
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** Mean alone does not determine spread or shape; distributions can differ widely.
#
# </details>

# %% [markdown]
# ## Statistics: Hypothesis Testing

# %% [markdown]
# ### Q33
# **A 95% CI for a mean that does NOT include 0 implies (for testing H0: μ=0, two-sided, α=0.05):**
#
# - **A**. Reject H0
# - **B**. Fail to reject H0
# - **C**. Cannot decide
# - **D**. Power is 1
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** If 0 is outside the 95% CI, the two-sided test at 5% rejects H0.
#
# </details>

# %% [markdown]
# ### Q34
# **A p-value is computed under:**
#
# - **A**. The alternative hypothesis
# - **B**. The null hypothesis
# - **C**. No hypothesis
# - **D**. The posterior distribution
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** p-value assumes H0 is true.
#
# </details>

# %% [markdown]
# ### Q35
# **A test with low power is more likely to:**
#
# - **A**. Miss a real effect (Type II error)
# - **B**. Inflate Type I error automatically
# - **C**. Guarantee significance
# - **D**. Make estimates unbiased
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** Low power means failing to detect true effects.
#
# </details>

# %% [markdown]
# ### Q36
# **A two-sided test rejects at α=0.05. Compared to a one-sided test at α=0.05, the two-sided critical region is:**
#
# - **A**. Entirely on one tail
# - **B**. Split across both tails
# - **C**. Larger in each tail
# - **D**. Always identical
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Two-sided tests allocate α/2 to each tail.
#
# </details>

# %% [markdown]
# ### Q37
# **If p-value = 0.03 and α = 0.05, then:**
#
# - **A**. Fail to reject H0
# - **B**. Reject H0
# - **C**. Accept H0 as true
# - **D**. Power = 0.97
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Since p < α, reject H0 at the 5% level.
#
# </details>

# %% [markdown]
# ### Q38
# **Multiple testing increases the chance of:**
#
# - **A**. Type I errors overall
# - **B**. Perfect accuracy
# - **C**. Zero false positives
# - **D**. Lower variance always
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** More tests inflate family-wise error without correction.
#
# </details>

# %% [markdown]
# ### Q39
# **Power of a test is:**
#
# - **A**. 1−α
# - **B**. 1−β
# - **C**. α/β
# - **D**. β/α
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Power is the probability of correctly rejecting a false null.
#
# </details>

# %% [markdown]
# ### Q40
# **The significance level α controls:**
#
# - **A**. Type II error rate
# - **B**. Type I error rate
# - **C**. Effect size
# - **D**. Sample variance
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** α is the probability of rejecting a true null hypothesis (Type I error).
#
# </details>

# %% [markdown]
# ### Q41
# **Type II error (β) is the probability of:**
#
# - **A**. Rejecting a true null
# - **B**. Failing to reject a false null
# - **C**. Rejecting a false null
# - **D**. Accepting the alternative
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** β is missing a real effect (false negative).
#
# </details>

# %% [markdown]
# ### Q42
# **When the null is composite and nuisance parameters exist, a common large-sample approach is to use:**
#
# - **A**. Exact binomial test always
# - **B**. Likelihood ratio / Wald / Score tests
# - **C**. Only t-tests
# - **D**. Only permutation tests
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** LR/Wald/Score are standard asymptotic tests with nuisance parameters.
#
# </details>

# %% [markdown]
# ## Statistics: Practice Calculations

# %% [markdown]
# ### Q43
# **A sample mean is 50, population σ is 10, and n=25. What is the standard error of the mean?**
#
# - **A**. 10
# - **B**. 5
# - **C**. 2
# - **D**. 0.4
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** SE = σ/√n = 10/5 = 2.
#
# </details>

# %% [markdown]
# ### Q44
# **A z-test for mean uses z = (x̄ − μ0)/(σ/√n). If x̄−μ0 is fixed and n quadruples, z will:**
#
# - **A**. Halve
# - **B**. Double
# - **C**. Stay same
# - **D**. Become 0
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** √n doubles when n quadruples, so denominator halves, z doubles.
#
# </details>

# %% [markdown]
# ### Q45
# **For a two-tailed test at α=0.05, the critical values for z are approximately:**
#
# - **A**. ±1.28
# - **B**. ±1.64
# - **C**. ±1.96
# - **D**. ±2.58
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** Two-sided 5% uses 2.5% in each tail → ±1.96.
#
# </details>

# %% [markdown]
# ### Q46
# **If correlation r = 0.0, the best conclusion is:**
#
# - **A**. No relationship at all
# - **B**. No linear relationship (could be non-linear)
# - **C**. Perfect negative relation
# - **D**. Causation is absent
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Zero correlation implies no linear association, not necessarily no association.
#
# </details>

# %% [markdown]
# ### Q47
# **If Var(X)=4 and Var(Y)=9 and Corr(X,Y)=0.5, then Cov(X,Y) equals:**
#
# - **A**. 1
# - **B**. 2
# - **C**. 3
# - **D**. 6
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** Cov = Corr·σx·σy = 0.5·2·3 = 3.
#
# </details>

# %% [markdown]
# ## Statistics: Probability & Sampling

# %% [markdown]
# ### Q48
# **A 95% confidence interval for a mean most correctly means:**
#
# - **A**. 95% probability the parameter lies in this specific interval
# - **B**. Over repeated samples, 95% of such intervals contain the true mean
# - **C**. 95% of the data lie in the interval
# - **D**. The null hypothesis is true with 95% probability
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Frequentist CI has repeated-sampling coverage interpretation.
#
# </details>

# %% [markdown]
# ### Q49
# **A sampling distribution refers to:**
#
# - **A**. Distribution of raw data
# - **B**. Distribution of a statistic across repeated samples
# - **C**. Distribution of residuals only
# - **D**. Distribution of p-values always
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Sampling distribution describes variability of a statistic under repeated sampling.
#
# </details>

# %% [markdown]
# ### Q50
# **As sample size increases, the standard error of the mean:**
#
# - **A**. Increases
# - **B**. Decreases proportionally to 1/√n
# - **C**. Stays constant
# - **D**. Becomes negative
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** SE( x̄ ) = σ/√n, so it shrinks as n grows.
#
# </details>

# %% [markdown]
# ### Q51
# **If events A and B are independent, then P(A ∩ B) equals:**
#
# - **A**. P(A)+P(B)
# - **B**. P(A)−P(B)
# - **C**. P(A)P(B)
# - **D**. P(A)/P(B)
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** Independence implies multiplication of probabilities.
#
# </details>

# %% [markdown]
# ### Q52
# **In simple random sampling without replacement from a finite population, the SE of the mean is adjusted by:**
#
# - **A**. Z-score inflation
# - **B**. Finite population correction factor
# - **C**. Chi-square scaling
# - **D**. Ridge penalty
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** FPC = √((N−n)/(N−1)) reduces SE when sampling fraction is large.
#
# </details>

# %% [markdown]
# ## Statistics: Regression & Inference

# %% [markdown]
# ### Q53
# **A robust remedy for influential outliers in regression (when you still want a linear model) is:**
#
# - **A**. Only increase learning rate
# - **B**. Use robust regression (Huber/RANSAC) or diagnose leverage/influence
# - **C**. Remove intercept always
# - **D**. Use softmax
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Robust regression/influence diagnostics reduce outlier impact without arbitrary deletion.
#
# </details>

# %% [markdown]
# ### Q54
# **Heteroskedasticity affects OLS by:**
#
# - **A**. Making coefficients biased
# - **B**. Invalidating standard errors if uncorrected
# - **C**. Making R² undefined
# - **D**. Preventing prediction
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Coefficients remain unbiased (under exogeneity), but usual SEs are wrong.
#
# </details>

# %% [markdown]
# ### Q55
# **If X is measured with classical measurement error (noise), OLS slope on X is typically:**
#
# - **A**. Upward biased
# - **B**. Downward biased (attenuation)
# - **C**. Unbiased always
# - **D**. Undefined
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Classical measurement error in X attenuates the slope toward zero.
#
# </details>

# %% [markdown]
# ### Q56
# **In logistic regression, the model is linear in:**
#
# - **A**. Probability p
# - **B**. Odds p/(1−p)
# - **C**. Log-odds log(p/(1−p))
# - **D**. Class labels
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** Logistic regression is linear in the logit (log-odds).
#
# </details>

# %% [markdown]
# ### Q57
# **Multicollinearity primarily increases:**
#
# - **A**. Bias
# - **B**. Standard errors
# - **C**. R² always decreases
# - **D**. Sample size
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Collinearity inflates variance of coefficient estimates.
#
# </details>

# %% [markdown]
# ### Q58
# **Omitted variable bias occurs when omitted Z:**
#
# - **A**. Is uncorrelated with X and affects Y
# - **B**. Is correlated with X and affects Y
# - **C**. Is correlated with Y but not X
# - **D**. Only affects X
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Bias requires Z affects Y and correlates with an included regressor.
#
# </details>

# %% [markdown]
# ### Q59
# **R² measures:**
#
# - **A**. Causality
# - **B**. Fraction of variance in Y explained by the model
# - **C**. Whether coefficients are unbiased
# - **D**. Whether residuals are normal
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** R² summarizes explained variance, not causality.
#
# </details>

# %% [markdown]
# ### Q60
# **The key condition for unbiased OLS estimates is:**
#
# - **A**. Normal X
# - **B**. E[ε|X]=0
# - **C**. Homoskedasticity only
# - **D**. Large sample only
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Zero conditional mean (exogeneity) is crucial for unbiasedness.
#
# </details>

# %% [markdown]
# ## Statistics: Time Series (Practice)

# %% [markdown]
# ### Q61
# **A 'naive' forecast for next period often equals:**
#
# - **A**. Mean of entire series
# - **B**. Last observed value
# - **C**. Zero always
# - **D**. Seasonal average only
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Naive forecast uses last value (random walk baseline).
#
# </details>

# %% [markdown]
# ### Q62
# **A stationary time series typically has:**
#
# - **A**. Constant mean/variance over time
# - **B**. Always increasing trend
# - **C**. No seasonality allowed
# - **D**. No noise
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** Stationarity implies stable statistical properties.
#
# </details>

# %% [markdown]
# ### Q63
# **ACF that decays slowly and PACF that cuts off after lag 1 often suggests:**
#
# - **A**. MA(1)
# - **B**. AR(1)
# - **C**. White noise
# - **D**. Seasonal ARIMA only
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** AR(1) often shows PACF cutoff at lag 1 and ACF tailing off.
#
# </details>

# %% [markdown]
# ### Q64
# **Autocorrelation means:**
#
# - **A**. Variables are independent
# - **B**. Current values are correlated with past values
# - **C**. Data are categorical
# - **D**. No trend
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Time series often have dependence across time lags.
#
# </details>

# %% [markdown]
# ### Q65
# **For forecasting with strong seasonality, a common classical baseline is:**
#
# - **A**. K-means
# - **B**. SARIMA or ETS (Holt-Winters)
# - **C**. Naive Bayes
# - **D**. PCA
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** SARIMA/ETS handle seasonality and trend in classical forecasting.
#
# </details>

# %% [markdown]
# ### Q66
# **MAPE is problematic when actuals contain zeros because:**
#
# - **A**. It becomes undefined or explodes
# - **B**. It always equals MAE
# - **C**. It cannot be computed for positive data
# - **D**. It favors large errors
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** Division by (near) zero makes MAPE unstable.
#
# </details>

# %% [markdown]
# ### Q67
# **Random K-fold CV is usually inappropriate for time series because it:**
#
# - **A**. Uses too much data
# - **B**. Breaks temporal order and leaks future information
# - **C**. Always reduces bias
# - **D**. Is required by ARIMA
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Time order must be preserved to avoid look-ahead leakage.
#
# </details>

# %% [markdown]
# ## AI-Assisted Data Analytics and Insights

# %% [markdown]
# ### Q68
# **A good evaluation for LLM-generated insights includes:**
#
# - **A**. Only BLEU score
# - **B**. Factuality checks against source data and consistency tests
# - **C**. Random selection of answers
# - **D**. Only latency
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Analytics insights must be fact-checked against authoritative data.
#
# </details>

# %% [markdown]
# ### Q69
# **A major risk when using LLMs for analytics summaries is:**
#
# - **A**. Higher GPU costs only
# - **B**. Hallucination (confident but incorrect statements)
# - **C**. Inability to generate text
# - **D**. Always perfect factual accuracy
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Hallucinations are a known risk—use grounding, verification, citations.
#
# </details>

# %% [markdown]
# ### Q70
# **Grounding an LLM response to a database is best done by:**
#
# - **A**. Letting it guess
# - **B**. Retrieval + citation of sources + executing/verifying queries
# - **C**. Increasing temperature
# - **D**. Removing constraints
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** RAG + verification reduces hallucination and improves trust.
#
# </details>

# %% [markdown]
# ## Applications of Neural Networks: Computer Vision

# %% [markdown]
# ### Q71
# **Data augmentation in vision mainly helps by:**
#
# - **A**. Reducing dataset size
# - **B**. Improving generalization by simulating plausible variations
# - **C**. Making images grayscale only
# - **D**. Removing the need for validation
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Augmentation increases effective data diversity.
#
# </details>

# %% [markdown]
# ### Q72
# **The most common architecture family for image tasks is:**
#
# - **A**. CNN (Convolutional Neural Network)
# - **B**. KNN
# - **C**. ARIMA
# - **D**. Apriori
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** CNNs exploit spatial locality via convolutions.
#
# </details>

# %% [markdown]
# ### Q73
# **Why do CNNs use convolution kernels?**
#
# - **A**. To ignore spatial structure
# - **B**. To exploit local receptive fields and parameter sharing
# - **C**. To increase parameters drastically
# - **D**. To replace labels
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Convolutions capture local patterns efficiently via shared weights.
#
# </details>

# %% [markdown]
# ## Applications of Neural Networks: Natural Language Processing

# %% [markdown]
# ### Q74
# **Tokenization in LLM pipelines is the process of:**
#
# - **A**. Training GPUs
# - **B**. Converting text into discrete units (tokens) the model can process
# - **C**. Removing all punctuation always
# - **D**. Computing p-values
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Tokenization maps text to model-consumable token IDs.
#
# </details>

# %% [markdown]
# ### Q75
# **Transformers are especially effective for NLP because they use:**
#
# - **A**. Only convolution layers
# - **B**. Attention mechanisms to model long-range dependencies
# - **C**. Only decision trees
# - **D**. K-means clustering
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Self-attention captures context across long sequences.
#
# </details>

# %% [markdown]
# ### Q76
# **Why is attention superior to plain RNNs for long contexts (in many cases)?**
#
# - **A**. Attention cannot parallelize
# - **B**. Attention provides direct paths between distant tokens and parallel computation
# - **C**. Attention removes embeddings
# - **D**. Attention guarantees zero errors
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Self-attention models long-range dependencies and parallelizes better.
#
# </details>

# %% [markdown]
# ## Building Blocks of Neural Networks

# %% [markdown]
# ### Q77
# **In a neuron, the role of the activation function is to:**
#
# - **A**. Store weights permanently
# - **B**. Introduce non-linearity so the network can learn complex patterns
# - **C**. Randomly shuffle inputs
# - **D**. Compute the loss directly
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Without activation, multiple layers collapse into a linear mapping.
#
# </details>

# %% [markdown]
# ### Q78
# **Which statement about Softmax is correct?**
#
# - **A**. It is typically used in hidden layers to avoid nonlinearity
# - **B**. It converts logits into a probability distribution over classes
# - **C**. It outputs values in (-∞,∞)
# - **D**. It prevents backpropagation
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Softmax maps logits to probabilities that sum to 1.
#
# </details>

# %% [markdown]
# ### Q79
# **Why can sigmoid activations be problematic in deep hidden layers?**
#
# - **A**. They are linear
# - **B**. They can saturate causing vanishing gradients
# - **C**. They require GPUs
# - **D**. They remove nonlinearity
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Saturation near 0/1 yields tiny gradients, slowing learning.
#
# </details>

# %% [markdown]
# ## Building Your First ML Model

# %% [markdown]
# ### Q80
# **A pipeline object (e.g., in scikit-learn) helps by:**
#
# - **A**. Running SQL
# - **B**. Bundling preprocessing + model to prevent leakage and simplify deployment
# - **C**. Rendering charts
# - **D**. Creating dashboards
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Pipelines ensure transforms are fit on train only and applied consistently.
#
# </details>

# %% [markdown]
# ### Q81
# **A proper ML workflow should avoid:**
#
# - **A**. Using a train/test split
# - **B**. Fitting preprocessing (like scaling) on the full dataset before splitting
# - **C**. Evaluating on held-out data
# - **D**. Using cross-validation
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** That causes data leakage.
#
# </details>

# %% [markdown]
# ### Q82
# **Which is the best reason to keep a final test set untouched until the end?**
#
# - **A**. To make training slower
# - **B**. To avoid optimistic bias in performance estimation
# - **C**. To increase variance
# - **D**. To tune hyperparameters on it
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Using the test set for decisions leaks information and inflates performance.
#
# </details>

# %% [markdown]
# ## Clustering & Time Series Forecasting

# %% [markdown]
# ### Q83
# **For time series cross-validation, the most appropriate split is usually:**
#
# - **A**. Random K-fold
# - **B**. Forward-chaining (walk-forward) split
# - **C**. Stratified shuffle
# - **D**. Leave-one-out random
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Time series CV preserves temporal order (walk-forward).
#
# </details>

# %% [markdown]
# ### Q84
# **When evaluating forecasts for intermittent demand, a common pitfall metric is:**
#
# - **A**. MAPE (can be unstable with zeros)
# - **B**. MAE
# - **C**. RMSE
# - **D**. Pinball loss
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** MAPE can blow up when actuals are near zero or zero.
#
# </details>

# %% [markdown]
# ### Q85
# **Which method is primarily designed for time series forecasting?**
#
# - **A**. K-means
# - **B**. ARIMA
# - **C**. PCA
# - **D**. DBSCAN
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** ARIMA is a classic forecasting model.
#
# </details>

# %% [markdown]
# ## Creating dashboards for real-time business monitoring with Tableau

# %% [markdown]
# ### Q86
# **A KPI dashboard needs to highlight anomalies quickly. Which design is best?**
#
# - **A**. Many small pie charts
# - **B**. KPI tiles with thresholds + sparklines + alerting
# - **C**. One giant table only
# - **D**. 3D bubble chart
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** KPI tiles + thresholds + trends enable rapid scanning and anomaly detection.
#
# </details>

# %% [markdown]
# ### Q87
# **For near real-time monitoring, a common Tableau approach is:**
#
# - **A**. Embed the workbook as a static image
# - **B**. Use extracts only and never refresh
# - **C**. Use live connection or scheduled extract refresh and dashboard refresh controls
# - **D**. Disable filters to speed up visuals
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** Real-time/near-real-time comes from live connections or refreshed extracts.
#
# </details>

# %% [markdown]
# ### Q88
# **For operational monitoring, the most important filter design principle is:**
#
# - **A**. Hide filters
# - **B**. Keep filters minimal and aligned to user decisions (region, time, product)
# - **C**. Add all fields as filters
# - **D**. Use only text filters
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Filters should match real decisions; too many increase cognitive load and slow dashboards.
#
# </details>

# %% [markdown]
# ## Data Architecture: Foundations

# %% [markdown]
# ### Q89
# **A common purpose of a data catalog is to:**
#
# - **A**. Train models
# - **B**. Provide metadata, lineage, and discoverability
# - **C**. Replace ETL
# - **D**. Encrypt all data automatically
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Catalogs help users find, understand, and trust datasets.
#
# </details>

# %% [markdown]
# ### Q90
# **A data pipeline's main purpose is to:**
#
# - **A**. Draw charts only
# - **B**. Move/transform data from sources to destinations reliably
# - **C**. Replace databases
# - **D**. Train neural nets only
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Pipelines ingest, transform, validate, and deliver data for downstream use.
#
# </details>

# %% [markdown]
# ### Q91
# **A feature store primarily provides:**
#
# - **A**. Model checkpoint storage
# - **B**. Consistent feature definitions + online/offline serving
# - **C**. Dashboard rendering
# - **D**. Log compression
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** It standardizes feature computation and serves features for training/inference.
#
# </details>

# %% [markdown]
# ### Q92
# **Train/serve skew happens when:**
#
# - **A**. Training and inference use identical feature logic
# - **B**. Feature computation differs between training and inference
# - **C**. You use a GPU
# - **D**. Your dataset is small
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Different pipelines create mismatched features and degrade production performance.
#
# </details>

# %% [markdown]
# ## Data Lakes

# %% [markdown]
# ### Q93
# **A common governance challenge in data lakes is:**
#
# - **A**. Too many joins
# - **B**. Data swamp risk due to poor cataloging/metadata/quality controls
# - **C**. Lack of file formats
# - **D**. Too many CPUs
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Without metadata and quality controls, lakes become hard to use ('data swamp').
#
# </details>

# %% [markdown]
# ### Q94
# **A defining characteristic of a data lake is:**
#
# - **A**. Only structured data allowed
# - **B**. Stores raw data in its native format (schema-on-read)
# - **C**. Requires star schema
# - **D**. Cannot store files
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Lakes commonly use schema-on-read and store raw/semistructured/unstructured.
#
# </details>

# %% [markdown]
# ### Q95
# **Schema-on-read implies that:**
#
# - **A**. Schema is enforced strictly at ingestion
# - **B**. Schema is applied when data is queried/consumed
# - **C**. Data must be relational
# - **D**. Data cannot be governed
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Lakes often store raw data and interpret schema at query time.
#
# </details>

# %% [markdown]
# ## Data Preprocessing & Feature Engineering

# %% [markdown]
# ### Q96
# **One-hot encoding is used to:**
#
# - **A**. Convert images to grayscale
# - **B**. Convert categorical variables into numeric indicator columns
# - **C**. Remove outliers
# - **D**. Normalize text length
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** One-hot expands categories into binary columns.
#
# </details>

# %% [markdown]
# ### Q97
# **Target leakage happens when:**
#
# - **A**. You drop duplicates
# - **B**. Features include information not available at prediction time (or derived from target)
# - **C**. You standardize features
# - **D**. You shuffle rows
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Leakage gives the model unfair information and inflates validation performance.
#
# </details>

# %% [markdown]
# ### Q98
# **Which scaling method is more robust to outliers?**
#
# - **A**. StandardScaler (mean/std)
# - **B**. MinMaxScaler
# - **C**. RobustScaler (median/IQR)
# - **D**. No scaling ever
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** RobustScaler uses median/IQR, less sensitive to extreme values.
#
# </details>

# %% [markdown]
# ## Data Visualization & Storytelling

# %% [markdown]
# ### Q99
# **For comparing category values, the best default is usually:**
#
# - **A**. Pie chart
# - **B**. Bar chart
# - **C**. Radar chart
# - **D**. 3D donut
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Bar charts support accurate comparisons via aligned lengths.
#
# </details>

# %% [markdown]
# ### Q100
# **Truncating the y-axis in a bar chart is risky because it:**
#
# - **A**. Always improves clarity
# - **B**. Can exaggerate differences visually
# - **C**. Reduces variance
# - **D**. Prevents outliers
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Axis truncation can distort perceived magnitude.
#
# </details>

# %% [markdown]
# ### Q101
# **When encoding quantitative values, which channel is typically most precise for humans?**
#
# - **A**. Color hue
# - **B**. Area
# - **C**. Position on a common scale
# - **D**. 3D depth
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** Position on a common scale yields highest perceptual accuracy.
#
# </details>

# %% [markdown]
# ### Q102
# **Which approach best supports storytelling in a dashboard?**
#
# - **A**. Show everything at once
# - **B**. Highlight key KPIs + trends + annotations around changes
# - **C**. Hide definitions
# - **D**. Avoid titles
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Narrative structure: takeaway → evidence → action.
#
# </details>

# %% [markdown]
# ## Data Warehouses

# %% [markdown]
# ### Q103
# **A star schema is designed to:**
#
# - **A**. Optimize OLTP writes
# - **B**. Simplify analytics with a central fact table and dimension tables
# - **C**. Store images
# - **D**. Replace ETL
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Star schema supports fast slicing/dicing for analytics.
#
# </details>

# %% [markdown]
# ### Q104
# **Data warehouses are typically optimized for:**
#
# - **A**. High-frequency OLTP transactions
# - **B**. Analytical queries (OLAP), aggregations, and reporting
# - **C**. Storing raw unstructured logs only
# - **D**. Running mobile apps
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Warehouses are for analytics/reporting workloads.
#
# </details>

# %% [markdown]
# ### Q105
# **In a warehouse, slowly changing dimensions (SCD) Type 2 capture:**
#
# - **A**. Only current value
# - **B**. Full history by versioning dimension rows
# - **C**. Fact table duplicates
# - **D**. Streaming offsets
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Type 2 keeps historical versions with effective dates/flags.
#
# </details>

# %% [markdown]
# ### Q106
# **Which is a good reason to use surrogate keys in dimension tables?**
#
# - **A**. They increase query latency
# - **B**. They decouple warehouse keys from operational system keys and support SCD history
# - **C**. They prevent aggregations
# - **D**. They are required for JSON
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Surrogate keys simplify integration and help handle slowly changing dimensions.
#
# </details>

# %% [markdown]
# ## Designing A/B Tests and Experiments

# %% [markdown]
# ### Q107
# **In an A/B test with a strongly seasonal metric, the best practice is to:**
#
# - **A**. Run A first, then B next month
# - **B**. Randomize concurrently and run long enough to cover seasonality
# - **C**. Only test on weekends
# - **D**. Remove timestamps
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Concurrent randomization prevents time confounding; duration should cover seasonal cycles.
#
# </details>

# %% [markdown]
# ### Q108
# **Random assignment in an A/B test primarily helps reduce:**
#
# - **A**. Type II error
# - **B**. Selection bias / confounding
# - **C**. Sample size
# - **D**. Measurement error
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Randomization balances observed and unobserved confounders in expectation.
#
# </details>

# %% [markdown]
# ### Q109
# **Which change most directly increases statistical power (all else equal)?**
#
# - **A**. Decreasing sample size
# - **B**. Increasing variance
# - **C**. Increasing sample size
# - **D**. Increasing α to 0.001
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** Larger sample size reduces standard error and increases power.
#
# </details>

# %% [markdown]
# ## Foundation of AI Data Architecture

# %% [markdown]
# ### Q110
# **A common pattern to support both batch and streaming features is:**
#
# - **A**. Single CSV file
# - **B**. Lambda architecture or unified streaming/batch with consistent feature definitions
# - **C**. Only OLTP DB
# - **D**. Only Excel
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Consistency across batch/streaming avoids discrepancies and supports low-latency serving.
#
# </details>

# %% [markdown]
# ### Q111
# **In modern AI data platforms, a feature store is primarily used to:**
#
# - **A**. Store model weights
# - **B**. Store, manage, and serve reusable features consistently for training and inference
# - **C**. Visualize dashboards
# - **D**. Replace the data lake
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Feature stores reduce train/serve skew and improve reuse.
#
# </details>

# %% [markdown]
# ### Q112
# **Train/serve skew is most likely when:**
#
# - **A**. Features are identical in training and inference
# - **B**. Training features are computed differently than inference features
# - **C**. You use SGD
# - **D**. You use a GPU
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Mismatch in feature pipelines causes skew and degraded production performance.
#
# </details>

# %% [markdown]
# ## Hypothesis Testing Fundamentals

# %% [markdown]
# ### Q113
# **A test has significance level α=0.05. Which statement is correct?**
#
# - **A**. P(Type II error)=0.05
# - **B**. P(reject H₀ | H₀ true)=0.05
# - **C**. P(H₀ true)=0.05
# - **D**. Power=0.95
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** α controls the Type I error rate: rejecting a true null.
#
# </details>

# %% [markdown]
# ### Q114
# **In hypothesis testing, the p-value is best interpreted as:**
#
# - **A**. The probability that the null hypothesis is true
# - **B**. The probability of observing data as extreme as (or more extreme than) what we saw, assuming the null is true
# - **C**. The probability that the alternative hypothesis is true
# - **D**. The probability the test has high power
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** p-value is computed under H₀.
#
# </details>

# %% [markdown]
# ### Q115
# **You run 20 independent hypothesis tests at α=0.05 with all nulls true. What is the expected number of false positives?**
#
# - **A**. 0
# - **B**. 1
# - **C**. 5
# - **D**. 10
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Expected false positives = m·α = 20·0.05 = 1.
#
# </details>

# %% [markdown]
# ## Introduction Time Series

# %% [markdown]
# ### Q116
# **A key difference between time series data and typical tabular data is:**
#
# - **A**. Time series never has missing values
# - **B**. Observations are ordered in time and often autocorrelated
# - **C**. Time series cannot be visualized
# - **D**. Time series must be normally distributed
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Temporal ordering and autocorrelation are central.
#
# </details>

# %% [markdown]
# ### Q117
# **If a time series has trend and seasonality, a reasonable classical baseline model is:**
#
# - **A**. K-means
# - **B**. SARIMA or ETS (Holt-Winters)
# - **C**. Logistic regression
# - **D**. Apriori
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** SARIMA/ETS handle seasonality and trend in classical forecasting.
#
# </details>

# %% [markdown]
# ### Q118
# **Stationarity in time series typically means:**
#
# - **A**. Mean/variance change over time
# - **B**. Statistical properties (like mean/variance) are constant over time
# - **C**. Data has no noise
# - **D**. Data is always increasing
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Stationarity implies stable statistical properties across time.
#
# </details>

# %% [markdown]
# ## Introduction to LLM & Prompt Engineering - I

# %% [markdown]
# ### Q119
# **A good way to reduce hallucinations for factual Q&A is to:**
#
# - **A**. Increase temperature
# - **B**. Use retrieval-augmented generation and require citations
# - **C**. Ask the model to guess confidently
# - **D**. Remove context
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** RAG + citations anchors answers to sources.
#
# </details>

# %% [markdown]
# ### Q120
# **Which prompt technique is best for enforcing a strict output format (e.g., JSON schema)?**
#
# - **A**. Vague instruction only
# - **B**. Provide a schema + explicit constraints + examples (few-shot) and validate output
# - **C**. Use higher temperature
# - **D**. Use poetry style
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Constraints + schema + examples + validation improve format adherence.
#
# </details>

# %% [markdown]
# ### Q121
# **Which prompt technique provides examples of the desired input-output behavior?**
#
# - **A**. Zero-shot prompting
# - **B**. Few-shot prompting
# - **C**. Temperature tuning
# - **D**. Tokenization
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Few-shot includes demonstrations to steer the model.
#
# </details>

# %% [markdown]
# ## Introduction to Supervised learning

# %% [markdown]
# ### Q122
# **Regularization (L1/L2) mainly helps by:**
#
# - **A**. Increasing overfitting
# - **B**. Constraining coefficients to improve generalization
# - **C**. Removing all bias
# - **D**. Guaranteeing 100% accuracy
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Regularization penalizes complexity to reduce overfitting.
#
# </details>

# %% [markdown]
# ### Q123
# **Which is a supervised learning task?**
#
# - **A**. Clustering customers by behavior
# - **B**. Predicting house price from features
# - **C**. Topic modeling without labels
# - **D**. Dimensionality reduction with PCA
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Regression is supervised.
#
# </details>

# %% [markdown]
# ### Q124
# **Which metric is most appropriate for highly imbalanced binary classification when positives are rare?**
#
# - **A**. Accuracy
# - **B**. F1 / Precision-Recall AUC
# - **C**. R²
# - **D**. MAPE
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** PR-focused metrics reflect minority class performance better than accuracy.
#
# </details>

# %% [markdown]
# ## Introduction to Unsupervised learning

# %% [markdown]
# ### Q125
# **A common way to choose k in k-means is:**
#
# - **A**. Always k=2
# - **B**. Elbow method / silhouette score
# - **C**. Use accuracy
# - **D**. Use p-value
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Elbow/silhouette help select k based on compactness/separation.
#
# </details>

# %% [markdown]
# ### Q126
# **If you have no labels and want to group similar customers, you would start with:**
#
# - **A**. Logistic regression
# - **B**. K-means clustering
# - **C**. Linear regression
# - **D**. Naive Bayes
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** K-means is a common baseline for clustering.
#
# </details>

# %% [markdown]
# ### Q127
# **PCA is primarily used to:**
#
# - **A**. Predict labels
# - **B**. Reduce dimensionality by capturing variance directions
# - **C**. Cluster points
# - **D**. Encode strings
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** PCA finds orthogonal components that explain variance.
#
# </details>

# %% [markdown]
# ## Introduction to machine learning

# %% [markdown]
# ### Q128
# **Bias–variance tradeoff implies that increasing model complexity typically:**
#
# - **A**. Increases bias and decreases variance
# - **B**. Decreases bias and increases variance
# - **C**. Decreases both
# - **D**. Increases both always
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** More complex models fit training data better (lower bias) but can be more variable.
#
# </details>

# %% [markdown]
# ### Q129
# **Overfitting happens when a model:**
#
# - **A**. Performs well on training data but poorly on new data
# - **B**. Performs poorly on training data and well on test data
# - **C**. Has no parameters
# - **D**. Has zero variance
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** Overfitting = poor generalization.
#
# </details>

# %% [markdown]
# ### Q130
# **Why do we use a validation set (or CV) in ML?**
#
# - **A**. To make training faster only
# - **B**. To tune hyperparameters and estimate generalization without touching test set
# - **C**. To increase leakage
# - **D**. To avoid metrics
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Validation guides model selection while keeping test set unbiased.
#
# </details>

# %% [markdown]
# ## Introduction to tool: Tableau

# %% [markdown]
# ### Q131
# **In Tableau, a FIXED LOD expression is mainly used to:**
#
# - **A**. Create joins
# - **B**. Compute values at a specified level of detail regardless of view
# - **C**. Build parameters only
# - **D**. Refresh extracts
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** FIXED LOD locks aggregation at chosen dimensionality independent of the viz.
#
# </details>

# %% [markdown]
# ### Q132
# **In Tableau, the difference between Dimensions and Measures is:**
#
# - **A**. Dimensions are numeric; Measures are text
# - **B**. Dimensions are categorical/qualitative; Measures are quantitative/aggregatable
# - **C**. Measures cannot be aggregated
# - **D**. Dimensions are only dates
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Dimensions slice; Measures aggregate.
#
# </details>

# %% [markdown]
# ### Q133
# **To improve performance on large datasets, a common Tableau tactic is to:**
#
# - **A**. Use as many quick filters as possible
# - **B**. Use extracts, reduce high-cardinality dimensions, and optimize calculations
# - **C**. Use only maps
# - **D**. Disable aggregation
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Extracts and reducing cardinality/calcs typically improve performance.
#
# </details>

# %% [markdown]
# ## LLM & Prompt Engineering

# %% [markdown]
# ### Q134
# **A reliable way to reduce hallucinations in factual QA is:**
#
# - **A**. Increase temperature
# - **B**. Use RAG + citations/verification
# - **C**. Ask the model to guess
# - **D**. Remove constraints
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Grounding + verification reduces hallucination risk.
#
# </details>

# %% [markdown]
# ### Q135
# **Few-shot prompting means:**
#
# - **A**. No examples provided
# - **B**. Provide a few input-output examples to guide behavior
# - **C**. Increase temperature
# - **D**. Remove context
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Examples steer model behavior.
#
# </details>

# %% [markdown]
# ### Q136
# **For strict JSON output, the best prompting pattern is:**
#
# - **A**. Vague instructions
# - **B**. Provide schema + constraints + examples and validate
# - **C**. Use poetry style
# - **D**. Max temperature
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Schema + constraints + few-shot + validation improves format adherence.
#
# </details>

# %% [markdown]
# ### Q137
# **Which evaluation best checks whether an LLM-generated numeric insight matches source data?**
#
# - **A**. Style rubric only
# - **B**. Execute the underlying query / compute from source and compare
# - **C**. Higher temperature
# - **D**. More emojis
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Numerical claims should be verified against the authoritative data source.
#
# </details>

# %% [markdown]
# ## Machine Learning: Fundamentals

# %% [markdown]
# ### Q138
# **Bias–variance tradeoff: increasing complexity typically:**
#
# - **A**. Increases bias and decreases variance
# - **B**. Decreases bias and increases variance
# - **C**. Decreases both
# - **D**. Increases both always
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Complex models fit training better (lower bias) but vary more (higher variance).
#
# </details>

# %% [markdown]
# ### Q139
# **Data leakage in time series forecasting commonly occurs when:**
#
# - **A**. You use rolling features computed using future data
# - **B**. You use lags only
# - **C**. You plot the series
# - **D**. You use walk-forward CV
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** Features must be computed using information available at forecast origin only.
#
# </details>

# %% [markdown]
# ### Q140
# **For highly imbalanced classification, a better metric than accuracy is:**
#
# - **A**. Accuracy
# - **B**. F1 or PR-AUC
# - **C**. R²
# - **D**. MAPE
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** PR-focused metrics reflect rare positive performance.
#
# </details>

# %% [markdown]
# ### Q141
# **Overfitting means the model:**
#
# - **A**. Generalizes well
# - **B**. Fits training well but performs poorly on new data
# - **C**. Has no parameters
# - **D**. Has zero variance
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Overfitting indicates poor generalization.
#
# </details>

# %% [markdown]
# ### Q142
# **Target leakage occurs when:**
#
# - **A**. You standardize features
# - **B**. Features include information unavailable at prediction time
# - **C**. You drop duplicates
# - **D**. You shuffle rows
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Leakage inflates validation and fails in production.
#
# </details>

# %% [markdown]
# ### Q143
# **Which technique best detects overfitting during training?**
#
# - **A**. Compare training vs validation performance curves
# - **B**. Increase epochs always
# - **C**. Use only training data
# - **D**. Remove regularization
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** A widening gap (train improves while val degrades) indicates overfitting.
#
# </details>

# %% [markdown]
# ### Q144
# **Why standardize features for models like KNN or SVM (RBF)?**
#
# - **A**. It changes labels
# - **B**. Distance-based methods are sensitive to feature scale
# - **C**. It removes need for validation
# - **D**. It guarantees accuracy
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Scaling prevents one feature from dominating distances.
#
# </details>

# %% [markdown]
# ## Multivariable Regressions

# %% [markdown]
# ### Q145
# **In multiple regression, the coefficient of X₁ is interpreted as:**
#
# - **A**. Effect of X₁ on Y ignoring other variables
# - **B**. Effect of X₁ on Y holding other predictors constant
# - **C**. Correlation between X₁ and Y
# - **D**. Effect of Y on X₁
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** “Ceteris paribus” interpretation.
#
# </details>

# %% [markdown]
# ### Q146
# **Omitted variable bias occurs when the omitted variable Z is:**
#
# - **A**. Uncorrelated with X and affects Y
# - **B**. Correlated with X and affects Y
# - **C**. Correlated with Y but not X
# - **D**. Only correlated with X
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Bias requires Z affects Y and correlates with included regressor X.
#
# </details>

# %% [markdown]
# ### Q147
# **Which issue does multicollinearity mainly impact?**
#
# - **A**. Bias of coefficients
# - **B**. Variance (standard errors) of coefficients
# - **C**. Model nonlinearity
# - **D**. Data leakage
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Multicollinearity inflates variances/SEs; coefficients can remain unbiased.
#
# </details>

# %% [markdown]
# ## Neural Networks

# %% [markdown]
# ### Q148
# **Batch normalization mainly helps by:**
#
# - **A**. Adding noise to labels
# - **B**. Stabilizing activations and improving optimization
# - **C**. Increasing bias always
# - **D**. Removing need for validation
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** BN stabilizes internal activations, often allowing higher learning rates.
#
# </details>

# %% [markdown]
# ### Q149
# **For multi-label classification with K independent labels, the typical output activation is:**
#
# - **A**. Softmax
# - **B**. Sigmoid (K units)
# - **C**. Linear
# - **D**. Tanh
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Multi-label tasks treat each label independently, so use sigmoid per label.
#
# </details>

# %% [markdown]
# ### Q150
# **ReLU is defined as:**
#
# - **A**. 1/(1+e^{-x})
# - **B**. max(0,x)
# - **C**. x^2
# - **D**. log(x)
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** ReLU outputs 0 for negative x and x for positive x.
#
# </details>

# %% [markdown]
# ### Q151
# **Sigmoid in deep hidden layers can be problematic because:**
#
# - **A**. It's linear
# - **B**. It saturates causing vanishing gradients
# - **C**. It requires one-hot encoding
# - **D**. It prevents loss computation
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Saturation yields tiny gradients and slows learning.
#
# </details>

# %% [markdown]
# ### Q152
# **Softmax is typically used in the output layer for:**
#
# - **A**. Regression
# - **B**. Multi-class classification
# - **C**. Clustering
# - **D**. Time series smoothing
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Softmax produces a probability distribution over classes.
#
# </details>

# %% [markdown]
# ## Neural Networks in Action

# %% [markdown]
# ### Q153
# **Batch normalization tends to help training by:**
#
# - **A**. Increasing label noise
# - **B**. Stabilizing activations/gradients and allowing higher learning rates
# - **C**. Removing the need for data
# - **D**. Preventing any overfitting
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** BN stabilizes internal distributions and improves optimization.
#
# </details>

# %% [markdown]
# ### Q154
# **Early stopping is best described as:**
#
# - **A**. Training until loss is zero
# - **B**. Stopping training when validation performance stops improving to avoid overfitting
# - **C**. Increasing epochs always
# - **D**. Dropping features randomly
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Early stopping monitors validation to prevent overfitting.
#
# </details>

# %% [markdown]
# ### Q155
# **Which technique is commonly used to reduce overfitting in neural networks?**
#
# - **A**. Dropout
# - **B**. Increasing learning rate indefinitely
# - **C**. Removing validation set
# - **D**. Using no activation functions
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** Dropout improves generalization.
#
# </details>

# %% [markdown]
# ## NoSQL

# %% [markdown]
# ### Q156
# **A common trade-off in many NoSQL systems is:**
#
# - **A**. Strong consistency always
# - **B**. Eventual consistency for higher availability
# - **C**. No horizontal scaling
# - **D**. Mandatory joins
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Many NoSQL systems relax consistency for availability/partition tolerance.
#
# </details>

# %% [markdown]
# ### Q157
# **A document database is best described as storing:**
#
# - **A**. Rows in normalized tables
# - **B**. JSON-like documents with flexible schema
# - **C**. Only graphs
# - **D**. Only time series
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Document stores keep semi-structured documents (e.g., JSON/BSON).
#
# </details>

# %% [markdown]
# ### Q158
# **When modeling one-to-many relationships in document DBs, a common pattern is:**
#
# - **A**. Always normalize into many collections with joins
# - **B**. Embed when read patterns need locality; reference when cardinality is large
# - **C**. Use foreign keys constraints
# - **D**. Avoid denormalization always
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Embedding improves read locality; referencing avoids huge documents.
#
# </details>

# %% [markdown]
# ## NoSQL Databases

# %% [markdown]
# ### Q159
# **A document database is often preferred over a relational model when:**
#
# - **A**. Many-to-many joins dominate
# - **B**. Data has evolving schema and nested attributes
# - **C**. Strict ACID across many tables is required
# - **D**. You need complex SQL analytics
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Document stores fit flexible, nested, rapidly evolving schemas.
#
# </details>

# %% [markdown]
# ### Q160
# **A key reason to use NoSQL (e.g., document stores) is:**
#
# - **A**. Strict schema enforcement
# - **B**. Ease of horizontal scaling and flexible schemas
# - **C**. Mandatory ACID transactions in all cases
# - **D**. Only supports SQL queries
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** NoSQL often trades strict schema/joins for flexibility and scale.
#
# </details>

# %% [markdown]
# ### Q161
# **A typical trade-off in many NoSQL systems is:**
#
# - **A**. Higher consistency always
# - **B**. Eventual consistency for higher availability/partition tolerance
# - **C**. No scaling
# - **D**. Mandatory joins
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Many NoSQL designs trade strict consistency for availability under partitions.
#
# </details>

# %% [markdown]
# ## Practical Classification Project

# %% [markdown]
# ### Q162
# **If accuracy is high but F1 score is near zero, the most likely issue is:**
#
# - **A**. Too many features
# - **B**. Severe class imbalance and the model predicts only the majority class
# - **C**. The dataset is too small
# - **D**. The model is too complex
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** High accuracy can happen by always predicting the majority class; F1 collapses for minority.
#
# </details>

# %% [markdown]
# ### Q163
# **If you must optimize F1, the best way to choose a threshold is to:**
#
# - **A**. Always 0.5
# - **B**. Sweep thresholds on validation set and pick max F1
# - **C**. Use training set only
# - **D**. Use accuracy
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Threshold should be tuned on validation based on the chosen metric.
#
# </details>

# %% [markdown]
# ### Q164
# **If you need higher recall on the minority class, the first lever to try is often:**
#
# - **A**. Increase decision threshold
# - **B**. Decrease decision threshold
# - **C**. Remove probabilities
# - **D**. Use MSE loss
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Lowering threshold increases recall (but may reduce precision).
#
# </details>

# %% [markdown]
# ### Q165
# **Which approach best addresses class imbalance during training?**
#
# - **A**. Remove minority class
# - **B**. Use class weights / resampling + appropriate metrics
# - **C**. Use accuracy only
# - **D**. Disable validation
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Class weights or resampling plus PR metrics is standard.
#
# </details>

# %% [markdown]
# ## Principles of effective data visualization

# %% [markdown]
# ### Q166
# **For comparing values across categories, the best default choice is usually:**
#
# - **A**. 3D pie chart
# - **B**. Line chart
# - **C**. Bar chart
# - **D**. Choropleth map
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** Bars are a strong default for categorical comparisons.
#
# </details>

# %% [markdown]
# ### Q167
# **Using a truncated y-axis in a bar chart is risky because it:**
#
# - **A**. Improves accuracy
# - **B**. Can exaggerate differences visually
# - **C**. Reduces file size
# - **D**. Guarantees better comprehension
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Truncation can distort perceived magnitude differences.
#
# </details>

# %% [markdown]
# ### Q168
# **When comparing two distributions across groups, which chart is typically most informative?**
#
# - **A**. Stacked 3D bar chart
# - **B**. Side-by-side box plots or violin plots
# - **C**. Single pie chart
# - **D**. Word cloud
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Box/violin show median, spread, and outliers across groups.
#
# </details>

# %% [markdown]
# ## Python Data Structures and Manipulation

# %% [markdown]
# ### Q169
# **To remove duplicates while preserving order in a list (Python 3.7+), a common approach is:**
#
# - **A**. `set(lst)`
# - **B**. `list(dict.fromkeys(lst))`
# - **C**. `sorted(lst)`
# - **D**. `lst.unique()`
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** `dict.fromkeys` preserves insertion order and removes duplicates.
#
# </details>

# %% [markdown]
# ### Q170
# **Which data structure is immutable in Python?**
#
# - **A**. list
# - **B**. dict
# - **C**. set
# - **D**. tuple
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** D
#
# **Explanation:** Tuples are immutable (though they can contain mutable objects).
#
# </details>

# %% [markdown]
# ### Q171
# **Which statement about Python dictionaries is correct?**
#
# - **A**. Keys must be mutable
# - **B**. Keys must be hashable (immutable-like)
# - **C**. Values must be numeric
# - **D**. Dicts are unordered always
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Dict keys must be hashable (e.g., str, int, tuple of immutables).
#
# </details>

# %% [markdown]
# ## Python Environment, Syntax, and Control Flow

# %% [markdown]
# ### Q172
# **In a `try/except/else/finally` block, the `else` clause runs when:**
#
# - **A**. An exception occurs
# - **B**. No exception occurs in the try block
# - **C**. Always runs
# - **D**. Only on KeyboardInterrupt
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** `else` executes only if `try` completes without exception.
#
# </details>

# %% [markdown]
# ### Q173
# **In Python, which keyword exits a loop immediately?**
#
# - **A**. stop
# - **B**. exit
# - **C**. break
# - **D**. return
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** `break` exits the nearest enclosing loop.
#
# </details>

# %% [markdown]
# ### Q174
# **What is the difference between `==` and `is` in Python?**
#
# - **A**. Same meaning always
# - **B**. `==` checks identity, `is` checks equality
# - **C**. `==` checks equality, `is` checks object identity
# - **D**. Both check types only
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** `==` compares values; `is` checks whether two references point to the same object.
#
# </details>

# %% [markdown]
# ## Python: Core

# %% [markdown]
# ### Q175
# **`==` vs `is` in Python:**
#
# - **A**. Same meaning
# - **B**. `==` checks identity, `is` checks equality
# - **C**. `==` checks equality, `is` checks identity
# - **D**. Both check types
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** C
#
# **Explanation:** `==` compares values; `is` compares object identity.
#
# </details>

# %% [markdown]
# ### Q176
# **In `try/except/else/finally`, the `else` block runs when:**
#
# - **A**. An exception occurs
# - **B**. No exception occurs in try
# - **C**. Always runs
# - **D**. Only for ValueError
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** `else` executes only if try completes successfully.
#
# </details>

# %% [markdown]
# ### Q177
# **Which data structure is immutable?**
#
# - **A**. list
# - **B**. dict
# - **C**. set
# - **D**. tuple
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** D
#
# **Explanation:** Tuples are immutable (though elements may be mutable objects).
#
# </details>

# %% [markdown]
# ### Q178
# **Which keyword exits a loop immediately?**
#
# - **A**. stop
# - **B**. break
# - **C**. pass
# - **D**. continue
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** `break` exits the nearest enclosing loop.
#
# </details>

# %% [markdown]
# ## Python: Data & File I/O

# %% [markdown]
# ### Q179
# **For robust API calls, you should:**
#
# - **A**. Ignore status codes
# - **B**. Handle timeouts/retries + validate schema
# - **C**. Sleep randomly
# - **D**. Only use GET
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Production calls should check status codes, retry, and validate responses.
#
# </details>

# %% [markdown]
# ### Q180
# **If an API is rate-limited, the best strategy is often:**
#
# - **A**. Infinite rapid retries
# - **B**. Exponential backoff with jitter
# - **C**. Disable error handling
# - **D**. Use print statements
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Backoff reduces request bursts and respects rate limits.
#
# </details>

# %% [markdown]
# ### Q181
# **The best practice to open a file safely is:**
#
# - **A**. `open()` without closing
# - **B**. `with open(...) as f:`
# - **C**. Copy-paste contents
# - **D**. Use recursion
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** `with` ensures automatic closing even if errors occur.
#
# </details>

# %% [markdown]
# ### Q182
# **When reading CSVs with inconsistent encodings, a practical approach is to:**
#
# - **A**. Hardcode utf-8 always
# - **B**. Try a small set of encodings with error handling
# - **C**. Convert file to PDF
# - **D**. Use recursion
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Try utf-8, latin-1, cp1252, and handle errors gracefully.
#
# </details>

# %% [markdown]
# ### Q183
# **When using `requests`, which parameter prevents your program from hanging indefinitely?**
#
# - **A**. headers
# - **B**. timeout
# - **C**. cookies
# - **D**. allow_redirects
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** `timeout=` sets a maximum wait time for the request.
#
# </details>

# %% [markdown]
# ## RDBMS & SQL

# %% [markdown]
# ### Q184
# **A FOREIGN KEY enforces:**
#
# - **A**. Faster GROUP BY
# - **B**. Referential integrity
# - **C**. Compression
# - **D**. Column ordering
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Child references must exist in the parent table.
#
# </details>

# %% [markdown]
# ### Q185
# **A PRIMARY KEY must be:**
#
# - **A**. Nullable
# - **B**. Unique and non-null
# - **C**. Text only
# - **D**. A foreign key
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Primary keys uniquely identify each row and cannot be NULL.
#
# </details>

# %% [markdown]
# ### Q186
# **In SQL, WHERE filters rows:**
#
# - **A**. After aggregation
# - **B**. Before aggregation
# - **C**. Only after ORDER BY
# - **D**. Only on SELECT aliases
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** WHERE applies before GROUP BY; HAVING filters groups after aggregation.
#
# </details>

# %% [markdown]
# ### Q187
# **Which clause is used to filter aggregated results?**
#
# - **A**. WHERE
# - **B**. HAVING
# - **C**. ORDER BY
# - **D**. DISTINCT
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** HAVING filters groups after GROUP BY.
#
# </details>

# %% [markdown]
# ### Q188
# **Which index best supports queries filtering by a single column and range scans?**
#
# - **A**. B-tree index
# - **B**. Full table scan
# - **C**. Bitmap always
# - **D**. Hash index only
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** B-tree supports ordered/range queries efficiently in most RDBMS.
#
# </details>

# %% [markdown]
# ### Q189
# **Which SQL query returns the count of distinct customers per region?**
#
# - **A**. SELECT region, COUNT(customer_id) FROM t GROUP BY region;
# - **B**. SELECT region, COUNT(DISTINCT customer_id) FROM t GROUP BY region;
# - **C**. SELECT COUNT(region, customer_id) FROM t;
# - **D**. SELECT region, DISTINCT COUNT(customer_id) FROM t;
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Use COUNT(DISTINCT ...) with GROUP BY for distinct counts per group.
#
# </details>

# %% [markdown]
# ## Realtime Data Streams

# %% [markdown]
# ### Q190
# **Event-time vs processing-time matters because:**
#
# - **A**. It changes GPU cost
# - **B**. Late or out-of-order events require correct windowing based on event-time
# - **C**. It removes need for keys
# - **D**. It forces batch only
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Event-time windowing handles late/out-of-order data more correctly.
#
# </details>

# %% [markdown]
# ### Q191
# **Idempotent consumers are important in at-least-once systems because:**
#
# - **A**. They increase duplicates
# - **B**. They prevent incorrect double-processing when duplicates occur
# - **C**. They slow throughput
# - **D**. They require SQL joins
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Duplicates can happen; idempotency avoids counting/acting twice.
#
# </details>

# %% [markdown]
# ### Q192
# **In streaming systems, “at-least-once” delivery means:**
#
# - **A**. Each message is delivered exactly once
# - **B**. Messages may be delivered more than once
# - **C**. Messages are never duplicated
# - **D**. Messages are always lost on failure
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** At-least-once can duplicate; consumers must be idempotent/deduplicate.
#
# </details>

# %% [markdown]
# ## Relational Database Management Systems

# %% [markdown]
# ### Q193
# **A foreign key primarily enforces:**
#
# - **A**. Uniqueness in the child table
# - **B**. Referential integrity between tables
# - **C**. Faster sorting
# - **D**. Column encryption
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** FK ensures child rows reference existing parent keys.
#
# </details>

# %% [markdown]
# ### Q194
# **The main purpose of a PRIMARY KEY is to:**
#
# - **A**. Allow NULL values
# - **B**. Uniquely identify each row in a table
# - **C**. Speed up every query automatically
# - **D**. Prevent joins
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Primary key enforces uniqueness and non-null.
#
# </details>

# %% [markdown]
# ### Q195
# **Which normal form goal most directly reduces update anomalies?**
#
# - **A**. Denormalization
# - **B**. Normalization (e.g., 3NF) by removing redundant dependencies
# - **C**. Using NULLs
# - **D**. Using TEXT for all columns
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Normalization reduces redundancy and update anomalies.
#
# </details>

# %% [markdown]
# ## Scripting, File I/O, and API Integration

# %% [markdown]
# ### Q196
# **For safely writing JSON to a file in Python, a common approach is:**
#
# - **A**. `open(...); f.write(str(obj))`
# - **B**. `json.dump(obj, f, ensure_ascii=False, indent=2)` inside `with open(...)`
# - **C**. Use pickle always
# - **D**. Use exec()
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** `json.dump` produces valid JSON; `with` manages file closure.
#
# </details>

# %% [markdown]
# ### Q197
# **The safest default for reading a large text file line-by-line is:**
#
# - **A**. `f.read()` into memory
# - **B**. Iterate over the file object in a `with open(...) as f:` block
# - **C**. Copy-paste into Python
# - **D**. Use recursion on file bytes
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Streaming line-by-line is memory efficient and `with` ensures closure.
#
# </details>

# %% [markdown]
# ### Q198
# **When calling a web API, which pattern is most robust?**
#
# - **A**. Ignore HTTP status codes
# - **B**. Handle timeouts/retries, check status codes, and validate response schema
# - **C**. Always sleep 1 hour
# - **D**. Use only GET
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Production-grade calls need retries/timeouts and validation.
#
# </details>

# %% [markdown]
# ## Single Variable Regressions

# %% [markdown]
# ### Q199
# **If residuals exhibit increasing variance with X, which fix is most appropriate for inference?**
#
# - **A**. Drop the intercept
# - **B**. Use robust (HC) standard errors
# - **C**. Add more noise
# - **D**. Use accuracy score
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Heteroskedasticity-robust SEs fix inference without changing coefficients.
#
# </details>

# %% [markdown]
# ### Q200
# **In simple linear regression, the slope coefficient represents:**
#
# - **A**. The average of Y
# - **B**. The change in Y for a one-unit increase in X (on average)
# - **C**. The correlation between X and Y
# - **D**. The variance of residuals
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Slope = expected change in Y per +1 in X.
#
# </details>

# %% [markdown]
# ### Q201
# **In simple linear regression, which condition is primarily needed for an unbiased slope estimate (in expectation)?**
#
# - **A**. Normality of X
# - **B**. Zero conditional mean: E[ε|X]=0
# - **C**. Homoskedasticity only
# - **D**. Large n
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Exogeneity (zero conditional mean) is key for unbiasedness.
#
# </details>

# %% [markdown]
# ## Storytelling with data

# %% [markdown]
# ### Q202
# **A good annotation strategy is to:**
#
# - **A**. Annotate every point
# - **B**. Annotate only the few points that explain the story (peaks, breaks, outliers)
# - **C**. Avoid text always
# - **D**. Use emojis only
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Selective annotations maintain clarity and focus attention.
#
# </details>

# %% [markdown]
# ### Q203
# **A key principle of effective data storytelling is:**
#
# - **A**. Maximize the number of charts per slide
# - **B**. Lead with the most important takeaway and support with evidence
# - **C**. Avoid annotations to keep charts clean
# - **D**. Always show raw data tables first
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Start with the “so what”, then justify.
#
# </details>

# %% [markdown]
# ### Q204
# **A narrative chart sequence should typically follow:**
#
# - **A**. Details → background → takeaway
# - **B**. Takeaway → supporting evidence → implications/action
# - **C**. Random order
# - **D**. Show code first
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Lead with insight, then evidence, then action/implications.
#
# </details>

# %% [markdown]
# ## Streaming & Real-time

# %% [markdown]
# ### Q205
# **Event-time windowing is important because:**
#
# - **A**. It reduces GPU costs
# - **B**. It handles late/out-of-order events correctly
# - **C**. It prevents partitioning
# - **D**. It removes the need for timestamps
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Event-time uses the time the event occurred, not when processed.
#
# </details>

# %% [markdown]
# ### Q206
# **Exactly-once semantics in streaming systems usually requires:**
#
# - **A**. No acknowledgements
# - **B**. Idempotent producers/consumers + transactional writes/checkpointing
# - **C**. Only UDP
# - **D**. Disabling retries
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Exactly-once typically uses transactions + checkpointing to avoid duplicates.
#
# </details>

# %% [markdown]
# ### Q207
# **Idempotent consumers matter in at-least-once systems because they:**
#
# - **A**. Create duplicates
# - **B**. Prevent double-processing effects under retries
# - **C**. Require no keys
# - **D**. Remove need for offsets
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Idempotency ensures repeated messages don't cause repeated side effects.
#
# </details>

# %% [markdown]
# ### Q208
# **If you need to compute unique users per minute with late events, which concept is most important?**
#
# - **A**. Batch ETL only
# - **B**. Event-time windows + watermarking
# - **C**. Random shuffling
# - **D**. Primary keys
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Event-time windows and watermarks manage late/out-of-order events correctly.
#
# </details>

# %% [markdown]
# ### Q209
# **In streaming, 'at-least-once' delivery means:**
#
# - **A**. No duplicates ever
# - **B**. Duplicates may occur
# - **C**. Exactly-once always
# - **D**. Messages are lost
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** At-least-once can re-deliver messages; consumers should deduplicate.
#
# </details>

# %% [markdown]
# ## Tableau (Concepts & Best Practices)

# %% [markdown]
# ### Q210
# **A FIXED LOD expression is used to:**
#
# - **A**. Create joins
# - **B**. Compute at a specified LOD regardless of view
# - **C**. Refresh extracts
# - **D**. Format tooltips
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** FIXED locks aggregation level independent of the viz.
#
# </details>

# %% [markdown]
# ### Q211
# **For operational monitoring, a good dashboard pattern is:**
#
# - **A**. Dense table only
# - **B**. KPI tiles + sparklines + thresholds
# - **C**. Only maps
# - **D**. Multiple 3D charts
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Supports fast scanning and anomaly detection.
#
# </details>

# %% [markdown]
# ### Q212
# **In Tableau, Dimensions are typically:**
#
# - **A**. Measures only
# - **B**. Categorical fields used to slice data
# - **C**. Always dates
# - **D**. Calculated fields only
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Dimensions define the level of detail; measures are aggregated.
#
# </details>

# %% [markdown]
# ### Q213
# **Performance tuning in Tableau commonly includes:**
#
# - **A**. More quick filters always
# - **B**. Reduce high-cardinality dims, optimize calcs, use extracts appropriately
# - **C**. Disable aggregation
# - **D**. Convert everything to strings
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** High-cardinality fields and heavy calcs often slow dashboards.
#
# </details>

# %% [markdown]
# ## Understanding Data Distributions

# %% [markdown]
# ### Q214
# **If a variable is right-skewed and strictly positive, which transformation often makes it more symmetric for modeling?**
#
# - **A**. Square transform
# - **B**. Log transform
# - **C**. Inverse logit transform
# - **D**. No transform ever helps
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Log transform commonly reduces right-skew for positive variables.
#
# </details>

# %% [markdown]
# ### Q215
# **Which plot is most appropriate to check whether a continuous variable is approximately normally distributed?**
#
# - **A**. Pie chart
# - **B**. Histogram with density curve
# - **C**. Stacked bar chart
# - **D**. Radar chart
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** A histogram (often with a density curve) helps assess shape (bell curve), skewness, and modality.
#
# </details>

# %% [markdown]
# ### Q216
# **You suspect a distribution has heavy tails compared to a normal distribution. Which diagnostic plot best supports this check?**
#
# - **A**. Box plot only
# - **B**. Q–Q plot against the normal distribution
# - **C**. Pie chart
# - **D**. Heatmap
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Q–Q plots reveal tail deviations from normality clearly (points bend away at extremes).
#
# </details>

# %% [markdown]
# ## Vector Databases & RAG

# %% [markdown]
# ### Q217
# **Chunking documents before embedding is mainly to:**
#
# - **A**. Increase hallucinations
# - **B**. Improve retrieval granularity and relevance
# - **C**. Reduce security
# - **D**. Eliminate metadata
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Chunks help retrieve the most relevant passages instead of entire documents.
#
# </details>

# %% [markdown]
# ### Q218
# **In RAG, the most important condition for reliable retrieval is:**
#
# - **A**. Use different embedding models for docs and queries
# - **B**. Use the same embedding model/space for docs and queries
# - **C**. No chunking needed
# - **D**. Disable citations
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Same embedding space ensures meaningful similarity; chunking/citations further help.
#
# </details>

# %% [markdown]
# ### Q219
# **Vector search typically finds nearest neighbors using:**
#
# - **A**. Exact string match
# - **B**. Similarity metrics like cosine distance
# - **C**. SQL LIKE only
# - **D**. Sort by timestamp
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Embedding similarity is measured with cosine/L2, etc.
#
# </details>

# %% [markdown]
# ### Q220
# **Which metadata field is most useful to store alongside embeddings for traceability?**
#
# - **A**. Random seed
# - **B**. Source document ID and chunk offsets
# - **C**. Screen resolution
# - **D**. Font size
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Doc IDs and offsets enable citing and retrieving the original source passage.
#
# </details>

# %% [markdown]
# ### Q221
# **Why use ANN (approximate nearest neighbor) indexing?**
#
# - **A**. Enforce schema
# - **B**. Speed similarity search at scale with controllable recall
# - **C**. Prevent embeddings
# - **D**. Compute p-values
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** ANN accelerates search in high-dimensional spaces with small accuracy trade-offs.
#
# </details>

# %% [markdown]
# ## Vector Databases and Embedding Storage

# %% [markdown]
# ### Q222
# **For semantic search in RAG, embeddings should be computed using:**
#
# - **A**. Random numbers
# - **B**. A consistent embedding model for both documents and queries
# - **C**. Different models per query
# - **D**. Only TF-IDF always
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Using the same embedding space ensures meaningful similarity comparisons.
#
# </details>

# %% [markdown]
# ### Q223
# **In vector databases, similarity search commonly uses:**
#
# - **A**. Exact string matching
# - **B**. Euclidean distance / cosine similarity over embeddings
# - **C**. Hash joins
# - **D**. Sorting by timestamp
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Embeddings are compared via distance/similarity metrics.
#
# </details>

# %% [markdown]
# ### Q224
# **Why are approximate nearest neighbor (ANN) indexes used for vector search?**
#
# - **A**. To enforce SQL constraints
# - **B**. To speed similarity search at scale with acceptable accuracy trade-offs
# - **C**. To store images as CSV
# - **D**. To compute p-values
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** ANN accelerates retrieval in high dimensions with controllable recall/latency.
#
# </details>

# %% [markdown]
# ## Warehouses, Lakes, Lakehouse

# %% [markdown]
# ### Q225
# **A common risk in a data lake without governance is:**
#
# - **A**. Too many indexes
# - **B**. Becoming a data swamp (poor metadata/quality)
# - **C**. Perfect discoverability
# - **D**. Zero duplicates
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Without catalog/quality controls, data becomes hard to find and trust.
#
# </details>

# %% [markdown]
# ### Q226
# **A data lake is often characterized by:**
#
# - **A**. Schema-on-write only
# - **B**. Schema-on-read and raw data storage
# - **C**. No governance needed
# - **D**. Only structured data
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Lakes store raw data and apply schema at query time.
#
# </details>

# %% [markdown]
# ### Q227
# **A lakehouse aims to combine:**
#
# - **A**. OLTP + CDN
# - **B**. Data lake storage with warehouse-like governance/performance
# - **C**. Only streaming
# - **D**. Only vector search
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Lakehouse blends lake flexibility with warehouse management and performance.
#
# </details>

# %% [markdown]
# ### Q228
# **Columnar storage in warehouses is especially beneficial for:**
#
# - **A**. Point lookups by primary key
# - **B**. Aggregations over few columns across many rows
# - **C**. High-frequency row updates
# - **D**. Transaction locking
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Columnar storage reads only needed columns and compresses well for analytics.
#
# </details>

# %% [markdown]
# ### Q229
# **Data warehouses are optimized for:**
#
# - **A**. OLTP transactions
# - **B**. OLAP analytics and aggregations
# - **C**. Running mobile UI
# - **D**. Image storage only
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Warehouses are designed for analytical workloads.
#
# </details>

# %% [markdown]
# ## Working with Libraries and Functions

# %% [markdown]
# ### Q230
# **A good practice for writing reusable functions is to:**
#
# - **A**. Hardcode file paths
# - **B**. Use clear inputs/outputs, docstrings, and avoid side-effects
# - **C**. Use global variables always
# - **D**. Print inside every function
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** Reusability improves with clear interfaces and minimal side-effects.
#
# </details>

# %% [markdown]
# ### Q231
# **In Python, `import numpy as np` does what?**
#
# - **A**. Imports NumPy and renames it to `np` for convenience
# - **B**. Installs NumPy
# - **C**. Deletes NumPy
# - **D**. Imports only pandas
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** A
#
# **Explanation:** It creates an alias `np`.
#
# </details>

# %% [markdown]
# ### Q232
# **Why is vectorization in NumPy typically faster than Python loops?**
#
# - **A**. It uses more RAM only
# - **B**. It executes optimized C/Fortran operations under the hood
# - **C**. It disables caching
# - **D**. It avoids arrays
#
# <details>
# <summary><b>Answer</b></summary>
#
# **Correct:** B
#
# **Explanation:** NumPy vectorized ops are implemented in optimized compiled code.
#
# </details>

# %% [markdown]
# ## Answer Key (Letters Only)
#
# | Q# | Ans | Section |
# |---:|:---:|:--------|
# | 1 | A | Statistics: A/B Testing & Experiments |
# | 2 | B | Statistics: A/B Testing & Experiments |
# | 3 | A | Statistics: A/B Testing & Experiments |
# | 4 | B | Statistics: A/B Testing & Experiments |
# | 5 | B | Statistics: A/B Testing & Experiments |
# | 6 | B | Statistics: A/B Testing & Experiments |
# | 7 | D | Statistics: Calculation Practice |
# | 8 | C | Statistics: Calculation Practice |
# | 9 | B | Statistics: Calculation Practice |
# | 10 | A | Statistics: Calculation Practice |
# | 11 | C | Statistics: Calculation Practice |
# | 12 | C | Statistics: Calculation Practice |
# | 13 | C | Statistics: Calculation Practice |
# | 14 | B | Statistics: Calculation Practice |
# | 15 | B | Statistics: Calculation Practice |
# | 16 | B | Statistics: Calculation Practice |
# | 17 | B | Statistics: Calculation Practice |
# | 18 | C | Statistics: Calculation Practice |
# | 19 | B | Statistics: Calculation Practice |
# | 20 | B | Statistics: Calculation Practice |
# | 21 | C | Statistics: Calculation Practice |
# | 22 | A | Statistics: Calculation Practice |
# | 23 | B | Statistics: Calculation Practice |
# | 24 | B | Statistics: Calculation Practice |
# | 25 | A | Statistics: Calculation Practice |
# | 26 | B | Statistics: Distributions & Descriptive Stats |
# | 27 | A | Statistics: Distributions & Descriptive Stats |
# | 28 | B | Statistics: Distributions & Descriptive Stats |
# | 29 | C | Statistics: Distributions & Descriptive Stats |
# | 30 | A | Statistics: Distributions & Descriptive Stats |
# | 31 | C | Statistics: Distributions & Descriptive Stats |
# | 32 | C | Statistics: Distributions & Descriptive Stats |
# | 33 | A | Statistics: Hypothesis Testing |
# | 34 | B | Statistics: Hypothesis Testing |
# | 35 | A | Statistics: Hypothesis Testing |
# | 36 | B | Statistics: Hypothesis Testing |
# | 37 | B | Statistics: Hypothesis Testing |
# | 38 | A | Statistics: Hypothesis Testing |
# | 39 | B | Statistics: Hypothesis Testing |
# | 40 | B | Statistics: Hypothesis Testing |
# | 41 | B | Statistics: Hypothesis Testing |
# | 42 | B | Statistics: Hypothesis Testing |
# | 43 | C | Statistics: Practice Calculations |
# | 44 | B | Statistics: Practice Calculations |
# | 45 | C | Statistics: Practice Calculations |
# | 46 | B | Statistics: Practice Calculations |
# | 47 | C | Statistics: Practice Calculations |
# | 48 | B | Statistics: Probability & Sampling |
# | 49 | B | Statistics: Probability & Sampling |
# | 50 | B | Statistics: Probability & Sampling |
# | 51 | C | Statistics: Probability & Sampling |
# | 52 | B | Statistics: Probability & Sampling |
# | 53 | B | Statistics: Regression & Inference |
# | 54 | B | Statistics: Regression & Inference |
# | 55 | B | Statistics: Regression & Inference |
# | 56 | C | Statistics: Regression & Inference |
# | 57 | B | Statistics: Regression & Inference |
# | 58 | B | Statistics: Regression & Inference |
# | 59 | B | Statistics: Regression & Inference |
# | 60 | B | Statistics: Regression & Inference |
# | 61 | B | Statistics: Time Series (Practice) |
# | 62 | A | Statistics: Time Series (Practice) |
# | 63 | B | Statistics: Time Series (Practice) |
# | 64 | B | Statistics: Time Series (Practice) |
# | 65 | B | Statistics: Time Series (Practice) |
# | 66 | A | Statistics: Time Series (Practice) |
# | 67 | B | Statistics: Time Series (Practice) |
# | 68 | B | AI-Assisted Data Analytics and Insights |
# | 69 | B | AI-Assisted Data Analytics and Insights |
# | 70 | B | AI-Assisted Data Analytics and Insights |
# | 71 | B | Applications of Neural Networks: Computer Vision |
# | 72 | A | Applications of Neural Networks: Computer Vision |
# | 73 | B | Applications of Neural Networks: Computer Vision |
# | 74 | B | Applications of Neural Networks: Natural Language Processing |
# | 75 | B | Applications of Neural Networks: Natural Language Processing |
# | 76 | B | Applications of Neural Networks: Natural Language Processing |
# | 77 | B | Building Blocks of Neural Networks |
# | 78 | B | Building Blocks of Neural Networks |
# | 79 | B | Building Blocks of Neural Networks |
# | 80 | B | Building Your First ML Model |
# | 81 | B | Building Your First ML Model |
# | 82 | B | Building Your First ML Model |
# | 83 | B | Clustering & Time Series Forecasting |
# | 84 | A | Clustering & Time Series Forecasting |
# | 85 | B | Clustering & Time Series Forecasting |
# | 86 | B | Creating dashboards for real-time business monitoring with Tableau |
# | 87 | C | Creating dashboards for real-time business monitoring with Tableau |
# | 88 | B | Creating dashboards for real-time business monitoring with Tableau |
# | 89 | B | Data Architecture: Foundations |
# | 90 | B | Data Architecture: Foundations |
# | 91 | B | Data Architecture: Foundations |
# | 92 | B | Data Architecture: Foundations |
# | 93 | B | Data Lakes |
# | 94 | B | Data Lakes |
# | 95 | B | Data Lakes |
# | 96 | B | Data Preprocessing & Feature Engineering |
# | 97 | B | Data Preprocessing & Feature Engineering |
# | 98 | C | Data Preprocessing & Feature Engineering |
# | 99 | B | Data Visualization & Storytelling |
# | 100 | B | Data Visualization & Storytelling |
# | 101 | C | Data Visualization & Storytelling |
# | 102 | B | Data Visualization & Storytelling |
# | 103 | B | Data Warehouses |
# | 104 | B | Data Warehouses |
# | 105 | B | Data Warehouses |
# | 106 | B | Data Warehouses |
# | 107 | B | Designing A/B Tests and Experiments |
# | 108 | B | Designing A/B Tests and Experiments |
# | 109 | C | Designing A/B Tests and Experiments |
# | 110 | B | Foundation of AI Data Architecture |
# | 111 | B | Foundation of AI Data Architecture |
# | 112 | B | Foundation of AI Data Architecture |
# | 113 | B | Hypothesis Testing Fundamentals |
# | 114 | B | Hypothesis Testing Fundamentals |
# | 115 | B | Hypothesis Testing Fundamentals |
# | 116 | B | Introduction Time Series |
# | 117 | B | Introduction Time Series |
# | 118 | B | Introduction Time Series |
# | 119 | B | Introduction to LLM & Prompt Engineering - I |
# | 120 | B | Introduction to LLM & Prompt Engineering - I |
# | 121 | B | Introduction to LLM & Prompt Engineering - I |
# | 122 | B | Introduction to Supervised learning |
# | 123 | B | Introduction to Supervised learning |
# | 124 | B | Introduction to Supervised learning |
# | 125 | B | Introduction to Unsupervised learning |
# | 126 | B | Introduction to Unsupervised learning |
# | 127 | B | Introduction to Unsupervised learning |
# | 128 | B | Introduction to machine learning |
# | 129 | A | Introduction to machine learning |
# | 130 | B | Introduction to machine learning |
# | 131 | B | Introduction to tool: Tableau |
# | 132 | B | Introduction to tool: Tableau |
# | 133 | B | Introduction to tool: Tableau |
# | 134 | B | LLM & Prompt Engineering |
# | 135 | B | LLM & Prompt Engineering |
# | 136 | B | LLM & Prompt Engineering |
# | 137 | B | LLM & Prompt Engineering |
# | 138 | B | Machine Learning: Fundamentals |
# | 139 | A | Machine Learning: Fundamentals |
# | 140 | B | Machine Learning: Fundamentals |
# | 141 | B | Machine Learning: Fundamentals |
# | 142 | B | Machine Learning: Fundamentals |
# | 143 | A | Machine Learning: Fundamentals |
# | 144 | B | Machine Learning: Fundamentals |
# | 145 | B | Multivariable Regressions |
# | 146 | B | Multivariable Regressions |
# | 147 | B | Multivariable Regressions |
# | 148 | B | Neural Networks |
# | 149 | B | Neural Networks |
# | 150 | B | Neural Networks |
# | 151 | B | Neural Networks |
# | 152 | B | Neural Networks |
# | 153 | B | Neural Networks in Action |
# | 154 | B | Neural Networks in Action |
# | 155 | A | Neural Networks in Action |
# | 156 | B | NoSQL |
# | 157 | B | NoSQL |
# | 158 | B | NoSQL |
# | 159 | B | NoSQL Databases |
# | 160 | B | NoSQL Databases |
# | 161 | B | NoSQL Databases |
# | 162 | B | Practical Classification Project |
# | 163 | B | Practical Classification Project |
# | 164 | B | Practical Classification Project |
# | 165 | B | Practical Classification Project |
# | 166 | C | Principles of effective data visualization |
# | 167 | B | Principles of effective data visualization |
# | 168 | B | Principles of effective data visualization |
# | 169 | B | Python Data Structures and Manipulation |
# | 170 | D | Python Data Structures and Manipulation |
# | 171 | B | Python Data Structures and Manipulation |
# | 172 | B | Python Environment, Syntax, and Control Flow |
# | 173 | C | Python Environment, Syntax, and Control Flow |
# | 174 | C | Python Environment, Syntax, and Control Flow |
# | 175 | C | Python: Core |
# | 176 | B | Python: Core |
# | 177 | D | Python: Core |
# | 178 | B | Python: Core |
# | 179 | B | Python: Data & File I/O |
# | 180 | B | Python: Data & File I/O |
# | 181 | B | Python: Data & File I/O |
# | 182 | B | Python: Data & File I/O |
# | 183 | B | Python: Data & File I/O |
# | 184 | B | RDBMS & SQL |
# | 185 | B | RDBMS & SQL |
# | 186 | B | RDBMS & SQL |
# | 187 | B | RDBMS & SQL |
# | 188 | A | RDBMS & SQL |
# | 189 | B | RDBMS & SQL |
# | 190 | B | Realtime Data Streams |
# | 191 | B | Realtime Data Streams |
# | 192 | B | Realtime Data Streams |
# | 193 | B | Relational Database Management Systems |
# | 194 | B | Relational Database Management Systems |
# | 195 | B | Relational Database Management Systems |
# | 196 | B | Scripting, File I/O, and API Integration |
# | 197 | B | Scripting, File I/O, and API Integration |
# | 198 | B | Scripting, File I/O, and API Integration |
# | 199 | B | Single Variable Regressions |
# | 200 | B | Single Variable Regressions |
# | 201 | B | Single Variable Regressions |
# | 202 | B | Storytelling with data |
# | 203 | B | Storytelling with data |
# | 204 | B | Storytelling with data |
# | 205 | B | Streaming & Real-time |
# | 206 | B | Streaming & Real-time |
# | 207 | B | Streaming & Real-time |
# | 208 | B | Streaming & Real-time |
# | 209 | B | Streaming & Real-time |
# | 210 | B | Tableau (Concepts & Best Practices) |
# | 211 | B | Tableau (Concepts & Best Practices) |
# | 212 | B | Tableau (Concepts & Best Practices) |
# | 213 | B | Tableau (Concepts & Best Practices) |
# | 214 | B | Understanding Data Distributions |
# | 215 | B | Understanding Data Distributions |
# | 216 | B | Understanding Data Distributions |
# | 217 | B | Vector Databases & RAG |
# | 218 | B | Vector Databases & RAG |
# | 219 | B | Vector Databases & RAG |
# | 220 | B | Vector Databases & RAG |
# | 221 | B | Vector Databases & RAG |
# | 222 | B | Vector Databases and Embedding Storage |
# | 223 | B | Vector Databases and Embedding Storage |
# | 224 | B | Vector Databases and Embedding Storage |
# | 225 | B | Warehouses, Lakes, Lakehouse |
# | 226 | B | Warehouses, Lakes, Lakehouse |
# | 227 | B | Warehouses, Lakes, Lakehouse |
# | 228 | B | Warehouses, Lakes, Lakehouse |
# | 229 | B | Warehouses, Lakes, Lakehouse |
# | 230 | B | Working with Libraries and Functions |
# | 231 | A | Working with Libraries and Functions |
# | 232 | B | Working with Libraries and Functions |
